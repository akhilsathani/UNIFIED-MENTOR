# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sklearn
import seaborn as sns

# %%
os.chdir(r"D:\Machinelearning\csv")

# %%
#Loading the data into dataframe
df=pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Now let's get an idea about the data
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [raw]
# ''' from the above we can interpret that the columns ['Sepal_length','Sepal_width'] are positively skewed which there are relatively more high values compared to low values.
# and the columns ['petal_length','petal_width'] are negatively skewed as the mean is less than the median(50%) so let's plot this.'''

# %% [markdown]
# # Univariate Analysis

# %%
sns.histplot(df['petal_length'],bins=50,kde=True,color="lightblue",edgecolor="white")
plt.title("Checking the skewness")
plt.show()

# %%
sns.histplot(df['petal_width'],bins=20,kde=True,color="lightblue",edgecolor="white")
plt.title("Checking the skewness")
plt.show()

# %%
#checking the positively skewed
sns.histplot(df['sepal_length'],bins=20,kde=True,color="lightblue",edgecolor="white")
plt.title("Checking the skewness")
plt.show()

# %%
sns.histplot(df['sepal_width'],bins=20,kde=True,color="lightblue",edgecolor="white")
plt.title("Checking the skewness")
plt.show()

# %%
#checking the type of column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Checking whether there are null values present or not
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#Checking how many unique values do we have in each column
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
#Now let's check whether we have imbalanced data or not
sns.countplot(df['species'])
plt.show()
# Out:
# C:\python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [raw]
# We can see the data is not imbalanced as each of the unique category has equal number of value_counts

# %% [raw]
# #To see the presence of outliers therefore we need to plot boxplot
# '''
#     a)If the Median is at the center of the Box and the whiskers are almost the
#        same on both the ends then the data is Normally Distributed.
#     b) If the Median lies closer to the First Quartile and if the whisker at the lower
#        end is shorter (as in the above example) then it has a Positive Skew (Right Skew).
#     c) If the Median lies closer to the Third Quartile and if the whisker at the
#        upper end is shorter than it has a Negative Skew (Left Skew).'''

# %%
sns.boxplot(x=df['sepal_length'],y=df['species'],data=df,orient='h')
plt.xlabel('sepal_length')
plt.ylabel('Species')
plt.show()

# %%
sns.boxplot(x=df['sepal_width'],y=df['species'],data=df,orient='h')
plt.xlabel('sepal_width')
plt.ylabel('Species')
plt.show()

# %%
sns.boxplot(x=df['petal_length'],y=df['species'],data=df,orient='h')
plt.xlabel('petal_length')
plt.ylabel('Species')
plt.show()

# %%
sns.boxplot(x=df['petal_width'],y=df['species'],data=df,orient='h')
plt.xlabel('petal_width')
plt.ylabel('Species')
plt.show()

# %% [raw]
# few outliers are present whereas setosa is normally distributed with sepal_length and sepal_width

# %% [raw]
# # Now,changing the species that is categorical column to numerical column for better visualisation

# %%
df['species'].replace(['setosa','virginica','versicolor'],[0,1,2],inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        1
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        1
#
# [150 rows x 5 columns]

# %% [markdown]
# # Bivariate Analysis

# %%
#Let's check the relationship between each column
sns.scatterplot(x=df['sepal_length'],y=df['sepal_width'],data=df,hue=df['species'])
plt.show()

# %%
sns.scatterplot(x=df['sepal_length'],y=df['petal_length'],data=df,hue=df['species'])
plt.show()

# %%
sns.scatterplot(x=df['sepal_length'],y=df['petal_width'],data=df,hue=df['species'])
plt.show()

# %%
sns.scatterplot(x=df['sepal_width'],y=df['petal_length'],data=df,hue=df['species'])
plt.show()

# %%
sns.scatterplot(x=df['sepal_width'],y=df['petal_width'],data=df,hue=df['species'])
plt.show()

# %%
sns.scatterplot(x=df['petal_width'],y=df['petal_length'],data=df,hue=df['species'])
plt.show()

# %%
#finding out the correlation between each column
plt.figure(figsize=(10,8))
sns.heatmap(data=df.iloc[:,0:4].corr(),annot=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# # from the above it can be concluded that the sepal_length is positively correlated with petal_length and petal_width but negatively correlated with sepal_width and vice-versa

# %% [markdown]
# # Overall, the EDA of the Iris dataset reveals that features like petal length and petal width are highly discriminative for distinguishing between the three Iris species.
